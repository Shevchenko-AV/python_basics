# %%
import pandas as pd
import numpy as np

def print_stats(col_name, low_q = 0.01, up_q = 0.99):
    print(col_name)
    print()
    print('Выбросы через межквартильный размах')
    q1 = df[col_name].quantile(0.25)
    q3 = df[col_name].quantile(0.75)
    iqr = q3 - q1
    lower_bound0 = q1 - (1.5 * iqr) 
    upper_bound0 = q3 + (1.5 * iqr)
    remove_surgery_outliers0 = df[df[col_name].between(lower_bound0, upper_bound0, inclusive='both')]
    print(df[~df[col_name].between(lower_bound0, upper_bound0, inclusive='both')][col_name])
    print('Разница со средним без выбросов ', df[col_name].mean() - remove_surgery_outliers0[col_name].mean())
    print('Разница с медианой без выбросов ', df[col_name].median() - remove_surgery_outliers0[col_name].median())
    print()
    print(f'Выбросы через {low_q}-{up_q} квантиль')
    lower_bound1 = df[col_name].quantile(low_q) 
    upper_bound1 = df[col_name].quantile(up_q)
    remove_surgery_outliers1 = df[df[col_name].between(lower_bound1, upper_bound1, inclusive='both')]
    print(df[~df[col_name].between(lower_bound1, upper_bound1, inclusive='both')][col_name])
    print('Разница среднего со средним без выбросов ', df[col_name].mean() - remove_surgery_outliers0[col_name].mean())
    print('Разница медианы с медианой без выбросов ', df[col_name].median() - remove_surgery_outliers0[col_name].median())
    print('Максимум ', df[col_name].max())
    print('Новый Максимум0 ', remove_surgery_outliers0[col_name].max())
    print('Новый Максимум1 ', remove_surgery_outliers1[col_name].max())
    print('Минимум ', df[col_name].min())
    print('Новый Минимум0 ', remove_surgery_outliers0[col_name].min())
    print('Новый Минимум1 ', remove_surgery_outliers1[col_name].min())
    print('Размах ', df[col_name].max() - df[col_name].min())
    print('Новый Размах0 ', remove_surgery_outliers0[col_name].max() - remove_surgery_outliers0[col_name].min())
    print('Новый Размах1 ', remove_surgery_outliers1[col_name].max() - remove_surgery_outliers1[col_name].min())
    print('Среднеарифметическое ', df[col_name].mean())
    print('Новое Среднеарифметическое0 ', remove_surgery_outliers0[col_name].mean())
    print('Новое Среднеарифметическое1 ', remove_surgery_outliers1[col_name].mean())
    print('Мода ', df[col_name].mode()[0])
    print('Новая Мода0 ', remove_surgery_outliers0[col_name].mode()[0])
    print('Новая Мода1 ', remove_surgery_outliers1[col_name].mode()[0])
    print('Медиана ', df[col_name].median())
    print('Новая Медиана0 ', remove_surgery_outliers0[col_name].median())
    print('Новая Медиана1 ', remove_surgery_outliers1[col_name].median())
    print('Второй квартиль (50% квантиль) ', df[col_name].quantile())
    print('Новый Второй квартиль0 (50% квантиль) ', remove_surgery_outliers0[col_name].quantile())
    print('Новый Второй квартиль1 (50% квантиль) ', remove_surgery_outliers1[col_name].quantile())
    print('Первый квартиль (25% квантиль) ', df[col_name].quantile(0.25))
    print('Новый Первый квартиль0 (25% квантиль) ', remove_surgery_outliers0[col_name].quantile(0.25))
    print('Новый Первый квартиль1 (25% квантиль) ', remove_surgery_outliers1[col_name].quantile(0.25))
    print('Третий квартиль (75% квантиль) ', df[col_name].quantile(0.75))
    print('Новый Третий квартиль0 (75% квантиль) ', remove_surgery_outliers0[col_name].quantile(0.75))
    print('Новый Третий квартиль1 (75% квантиль) ', remove_surgery_outliers1[col_name].quantile(0.75))
    print('Межквартильный размах ', df[col_name].quantile(0.75) - df[col_name].quantile(0.25))
    print('Новый Межквартильный размах0 ', remove_surgery_outliers0[col_name].quantile(0.75) - remove_surgery_outliers0[col_name].quantile(0.25))
    print('Новый Межквартильный размах1 ', remove_surgery_outliers1[col_name].quantile(0.75) - remove_surgery_outliers0[col_name].quantile(0.25))
    print('СКО (среднее отклонение) ', df[col_name].std())
    print('Новое СКО (среднее отклонение)0 ', remove_surgery_outliers0[col_name].std())
    print('Новое СКО (среднее отклонение)1 ', remove_surgery_outliers1[col_name].std())
    print('Дисперсия ', df[col_name].var())
    print('Новая Дисперсия0 ', remove_surgery_outliers0[col_name].var())
    print('Новая Дисперсия1 ', remove_surgery_outliers1[col_name].var())

url = 'https://raw.githubusercontent.com/obulygin/pyda_homeworks/master/statistics_basics/horse_data.csv'
col_names = ['surgery', # Качественный (проводилась хирургическая операция или нет)
             'age', # Качественный (моложе 6 месяцев или старше)
             'hospital_number', # Качественный (идентификатор лошади)
             'rectal_temperature', # Количественный дискретный (значение градусника)
             'pulse', # Количественный дискретный
             'respiratory_rate', # Количественный дискретный
             'temperature_of_extremities', # Качественный (категории температуры не в очерёдности градусов)
             'peripheral_pulse', 'mucous_membranes', 'capillary_refill_time',
             'pain', 'peristalsis', 'abdominal_distension', 'nasogastric_tube', 'nasogastric_reflux',
             'nasogastric_reflux_ph', 'rectal_examination', 'abdomen', 'packed_cell_volume', 'total_protein',
             'abdominocentesis_appearance', 'abdomcentesis_total_protein', 'outcome', 'surgical_lesion',
             'type_of_lesion1', 'type_of_lesion2', 'type_of_lesion3', 'cp_data']
df = pd.DataFrame()
try:
    df = pd.read_csv(url, names = col_names, na_values = '?')
finally:
    if df.empty:
        df = pd.read_csv('horse_data.csv', names = col_names, na_values = '?')
df = df[['surgery', 'age', 'rectal_temperature', 'pulse', 'respiratory_rate', 'temperature_of_extremities', 'pain', 'outcome']]
print('На основе предыдущих двух заданий необходимо вычислить корреляцию между столбцами rectal_temperature, respiratory_rate, temperature_of_extremities и pain, после этого можно делать выводы о способах удаления/заполнения пропусков')
print('До тех пор, пока мы не умеем работать с корреляциями, принимаем решение удалять строки с пропусками хотя бы 1 столбца')
df.head()
# Out:
# На основе предыдущих двух заданий необходимо вычислить корреляцию между столбцами rectal_temperature, respiratory_rate, temperature_of_extremities и pain, после этого можно делать выводы о способах удаления/заполнения пропусков
# До тех пор, пока мы не умеем работать с корреляциями, принимаем решение удалять строки с пропусками хотя бы 1 столбца
#    surgery  age  rectal_temperature  pulse  respiratory_rate  \
# 0      2.0    1                38.5   66.0              28.0
# 1      1.0    1                39.2   88.0              20.0
# 2      2.0    1                38.3   40.0              24.0
# 3      1.0    9                39.1  164.0              84.0
# 4      2.0    1                37.3  104.0              35.0
#
#    temperature_of_extremities  pain  outcome
# 0                         3.0   5.0      2.0
# 1                         NaN   3.0      3.0
# 2                         1.0   3.0      1.0
# 3                         4.0   2.0      2.0
# 4                         NaN   NaN      2.0

# %%
df = df.dropna(thresh=7) # Хотя бы 7 (из 8) столбцов должны быть заполнены
df.dropna(thresh=7).count()
# Out:
# surgery                       231
# age                           231
# rectal_temperature            208
# pulse                         228
# respiratory_rate              210
# temperature_of_extremities    216
# pain                          216
# outcome                       231
# dtype: int64

# %%
print_stats('surgery')
print('Вывод: Единственный пропуск без значения surgery - удалили строку')
print('Прежний Вывод (верный): Большинству лошадей проводили хирургическую операцию')
# Out:
# surgery
#
# Выбросы через межквартильный размах
# Series([], Name: surgery, dtype: float64)
# Разница со средним без выбросов  0.0
# Разница с медианой без выбросов  0.0
#
# Выбросы через 0.01-0.99 квантиль
# Series([], Name: surgery, dtype: float64)
# Разница среднего со средним без выбросов  0.0
# Разница медианы с медианой без выбросов  0.0
# Максимум  2.0
# Новый Максимум0  2.0
# Новый Максимум1  2.0
# Минимум  1.0
# Новый Минимум0  1.0
# Новый Минимум1  1.0
# Размах  1.0
# Новый Размах0  1.0
# Новый Размах1  1.0
# Среднеарифметическое  1.4155844155844155
# Новое Среднеарифметическое0  1.4155844155844155
# Новое Среднеарифметическое1  1.4155844155844155
# Мода  1.0
# Новая Мода0  1.0
# Новая Мода1  1.0
# Медиана  1.0
# Новая Медиана0  1.0
# Новая Медиана1  1.0
# Второй квартиль (50% квантиль)  1.0
# Новый Второй квартиль0 (50% квантиль)  1.0
# Новый Второй квартиль1 (50% квантиль)  1.0
# Первый квартиль (25% квантиль)  1.0
# Новый Первый квартиль0 (25% квантиль)  1.0
# Новый Первый квартиль1 (25% квантиль)  1.0
# Третий квартиль (75% квантиль)  2.0
# Новый Третий квартиль0 (75% квантиль)  2.0
# Новый Третий квартиль1 (75% квантиль)  2.0
# Межквартильный размах  1.0
# Новый Межквартильный размах0  1.0
# Новый Межквартильный размах1  1.0
# СКО (среднее отклонение)  0.4938926837486228
# Новое СКО (среднее отклонение)0  0.4938926837486228
# Новое СКО (среднее отклонение)1  0.4938926837486228
# Дисперсия  0.2439299830604171
# Новая Дисперсия0  0.2439299830604171
# Новая Дисперсия1  0.2439299830604171
# Вывод: Единственный пропуск без значения surgery - удалили строку
# Прежний Вывод (верный): Большинству лошадей проводили хирургическую операцию

# %%
print_stats('age', 0.01, 0.92)
print('Вывод: всего 17 из 231 лошадей не являются взрослыми, прежние вывод подтверждаются. Но если важно учитывать и невзрослых лошадей, не надо отсекать выбросы')
print('Прежний Вывод (верный): Большинство лошадей выборки являются взрослыми - больше 6 месяцев')
print('Примечание: в описании говорилось о значениях 1 и 2, в предоставленном файле - 1 и 9')
# Out:
# age
#
# Выбросы через межквартильный размах
# 3      9
# 9      9
# 13     9
# 16     9
# 23     9
# 55     9
# 75     9
# 82     9
# 103    9
# 109    9
# 135    9
# 191    9
# 212    9
# 244    9
# 252    9
# 255    9
# 275    9
# Name: age, dtype: int64
# Разница со средним без выбросов  0.5887445887445888
# Разница с медианой без выбросов  0.0
#
# Выбросы через 0.01-0.92 квантиль
# 3      9
# 9      9
# 13     9
# 16     9
# 23     9
# 55     9
# 75     9
# 82     9
# 103    9
# 109    9
# 135    9
# 191    9
# 212    9
# 244    9
# 252    9
# 255    9
# 275    9
# Name: age, dtype: int64
# Разница среднего со средним без выбросов  0.5887445887445888
# Разница медианы с медианой без выбросов  0.0
# Максимум  9
# Новый Максимум0  1
# Новый Максимум1  1
# Минимум  1
# Новый Минимум0  1
# Новый Минимум1  1
# Размах  8
# Новый Размах0  0
# Новый Размах1  0
# Среднеарифметическое  1.5887445887445888
# Новое Среднеарифметическое0  1.0
# Новое Среднеарифметическое1  1.0
# Мода  1
# Новая Мода0  1
# Новая Мода1  1
# Медиана  1.0
# Новая Медиана0  1.0
# Новая Медиана1  1.0
# Второй квартиль (50% квантиль)  1.0
# Новый Второй квартиль0 (50% квантиль)  1.0
# Новый Второй квартиль1 (50% квантиль)  1.0
# Первый квартиль (25% квантиль)  1.0
# Новый Первый квартиль0 (25% квантиль)  1.0
# Новый Первый квартиль1 (25% квантиль)  1.0
# Третий квартиль (75% квантиль)  1.0
# Новый Третий квартиль0 (75% квантиль)  1.0
# Новый Третий квартиль1 (75% квантиль)  1.0
# Межквартильный размах  0.0
# Новый Межквартильный размах0  0.0
# Новый Межквартильный размах1  0.0
# СКО (среднее отклонение)  2.093396175482535
# Новое СКО (среднее отклонение)0  0.0
# Новое СКО (среднее отклонение)1  0.0
# Дисперсия  4.3823075475249045
# Новая Дисперсия0  0.0
# Новая Дисперсия1  0.0
# Вывод: всего 17 из 231 лошадей не являются взрослыми, прежние вывод подтверждаются. Но если важно учитывать и невзрослых лошадей, не надо отсекать выбросы
# Прежний Вывод (верный): Большинство лошадей выборки являются взрослыми - больше 6 месяцев
# Примечание: в описании говорилось о значениях 1 и 2, в предоставленном файле - 1 и 9

# %%
print_stats('rectal_temperature')
print('Вывод: осталось 24 из 231 строк с пропусками, статистику теперь можно учитывать')
print('Прежний Вывод (для данной выборки достоверный): Большинство лошадей имеют температуру чуть выше нормы, но незначительно - 0.7 до градусов цельсия, т.к.орма 37.8, б')
print('Новый Вывод: столбец теперь можно учитывать в статистиках')
# Out:
# rectal_temperature
#
# Выбросы через межквартильный размах
# 8       NaN
# 16      NaN
# 20     39.9
# 34      NaN
# 35      NaN
# 44     35.4
# 54     40.3
# 57      NaN
# 65      NaN
# 75     39.7
# 80     36.4
# 86      NaN
# 91     40.3
# 99     39.6
# 101     NaN
# 105     NaN
# 110     NaN
# 118    36.5
# 145     NaN
# 167     NaN
# 178     NaN
# 191     NaN
# 193     NaN
# 219     NaN
# 222     NaN
# 238    36.1
# 242     NaN
# 251    36.6
# 253     NaN
# 259    40.8
# 265     NaN
# 272     NaN
# 281    40.0
# 282     NaN
# 295     NaN
# 298    36.5
# Name: rectal_temperature, dtype: float64
# Разница со средним без выбросов  0.010032051282045984
# Разница с медианой без выбросов  0.0
#
# Выбросы через 0.01-0.99 квантиль
# 8       NaN
# 16      NaN
# 34      NaN
# 35      NaN
# 44     35.4
# 54     40.3
# 57      NaN
# 65      NaN
# 80     36.4
# 86      NaN
# 91     40.3
# 101     NaN
# 105     NaN
# 110     NaN
# 145     NaN
# 167     NaN
# 178     NaN
# 191     NaN
# 193     NaN
# 219     NaN
# 222     NaN
# 238    36.1
# 242     NaN
# 253     NaN
# 259    40.8
# 265     NaN
# 272     NaN
# 282     NaN
# 295     NaN
# Name: rectal_temperature, dtype: float64
# Разница среднего со средним без выбросов  0.010032051282045984
# Разница медианы с медианой без выбросов  0.0
# Максимум  40.8
# Новый Максимум0  39.5
# Новый Максимум1  40.0
# Минимум  35.4
# Новый Минимум0  36.9
# Новый Минимум1  36.5
# Размах  5.399999999999999
# Новый Размах0  2.6000000000000014
# Новый Размах1  3.5
# Среднеарифметическое  38.16490384615384
# Новое Среднеарифметическое0  38.154871794871795
# Новое Среднеарифметическое1  38.163366336633665
# Мода  38.0
# Новая Мода0  38.0
# Новая Мода1  38.0
# Медиана  38.1
# Новая Медиана0  38.1
# Новая Медиана1  38.1
# Второй квартиль (50% квантиль)  38.1
# Новый Второй квартиль0 (50% квантиль)  38.1
# Новый Второй квартиль1 (50% квантиль)  38.1
# Первый квартиль (25% квантиль)  37.8
# Новый Первый квартиль0 (25% квантиль)  37.8
# Новый Первый квартиль1 (25% квантиль)  37.8
# Третий квартиль (75% квантиль)  38.5
# Новый Третий квартиль0 (75% квантиль)  38.5
# Новый Третий квартиль1 (75% квантиль)  38.5
# Межквартильный размах  0.7000000000000028
# Новый Межквартильный размах0  0.7000000000000028
# Новый Межквартильный размах1  0.7000000000000028
# СКО (среднее отклонение)  0.7234972701320421
# Новое СКО (среднее отклонение)0  0.5489581124748195
# Новое СКО (среднее отклонение)1  0.6200180983198991
# Дисперсия  0.5234482998885172
# Новая Дисперсия0  0.3013550092519166
# Новая Дисперсия1  0.384422442244224
# Вывод: осталось 24 из 231 строк с пропусками, статистику теперь можно учитывать
# Прежний Вывод (для данной выборки достоверный): Большинство лошадей имеют температуру чуть выше нормы, но незначительно - 0.7 до градусов цельсия, т.к.орма 37.8, б
# Новый Вывод: столбец теперь можно учитывать в статистиках

# %%
print_stats('pulse', 0.02, 0.98)
print('Вывод: осталось 3 пропуска из 231 строки, прежние статистики по этому столбцу можно применять дальше, опустив значения 150 и выше')
print('Прежний Вывод (верный): Большинство лошадей либо имели болезненные повреждения или находились в состоянии циркулярного шока - пульс выше нормы (которая 30-40)')
print('Прежний Вывод: если лошади испытывали боль/шок, нельзя по этому параметру сказать об атлетичности')
print('Примечание: для более точных результатов скорее всего необходимо учитывать корреляцию с показателем pain')
# Out:
# pulse
#
# Выбросы через межквартильный размах
# 3      164.0
# 55     160.0
# 83       NaN
# 182      NaN
# 204      NaN
# 255    184.0
# 275    150.0
# Name: pulse, dtype: float64
# Разница со средним без выбросов  1.6688596491228083
# Разница с медианой без выбросов  4.0
#
# Выбросы через 0.02-0.98 квантиль
# 3      164.0
# 55     160.0
# 76      38.0
# 83       NaN
# 182      NaN
# 203     36.0
# 204      NaN
# 242     36.0
# 255    184.0
# 275    150.0
# 276     36.0
# Name: pulse, dtype: float64
# Разница среднего со средним без выбросов  1.6688596491228083
# Разница медианы с медианой без выбросов  4.0
# Максимум  184.0
# Новый Максимум0  140.0
# Новый Максимум1  140.0
# Минимум  36.0
# Новый Минимум0  36.0
# Новый Минимум1  40.0
# Размах  148.0
# Новый Размах0  104.0
# Новый Размах1  100.0
# Среднеарифметическое  71.04385964912281
# Новое Среднеарифметическое0  69.375
# Новое Среднеарифметическое1  69.97272727272727
# Мода  48.0
# Новая Мода0  48.0
# Новая Мода1  48.0
# Медиана  64.0
# Новая Медиана0  60.0
# Новая Медиана1  64.0
# Второй квартиль (50% квантиль)  64.0
# Новый Второй квартиль0 (50% квантиль)  60.0
# Новый Второй квартиль1 (50% квантиль)  64.0
# Первый квартиль (25% квантиль)  48.0
# Новый Первый квартиль0 (25% квантиль)  48.0
# Новый Первый квартиль1 (25% квантиль)  48.0
# Третий квартиль (75% квантиль)  88.0
# Новый Третий квартиль0 (75% квантиль)  88.0
# Новый Третий квартиль1 (75% квантиль)  88.0
# Межквартильный размах  40.0
# Новый Межквартильный размах0  40.0
# Новый Межквартильный размах1  40.0
# СКО (среднее отклонение)  27.83934095594349
# Новое СКО (среднее отклонение)0  25.034550116819947
# Новое СКО (среднее отклонение)1  24.860876487819798
# Дисперсия  775.0289048612727
# Новая Дисперсия0  626.7286995515695
# Новая Дисперсия1  618.0631797426313
# Вывод: осталось 3 пропуска из 231 строки, прежние статистики по этому столбцу можно применять дальше, опустив значения 150 и выше
# Прежний Вывод (верный): Большинство лошадей либо имели болезненные повреждения или находились в состоянии циркулярного шока - пульс выше нормы (которая 30-40)
# Прежний Вывод: если лошади испытывали боль/шок, нельзя по этому параметру сказать об атлетичности
# Примечание: для более точных результатов скорее всего необходимо учитывать корреляцию с показателем pain

# %%
print_stats('respiratory_rate')
print('Вывод: осталось 21 строки с пропусками из 231, столбец теперь можно учитывать в статистиках (согласно мнению лектора о 20%)')
print('Прежний Вывод (верный): подтвердилось примечание из описания - слишком большие колебания по сравнению с нормой (8-10)')
print('Новый Вывод: соотношение выбросов/пропусков к общему числу элементов близко к rectal_temperature, стоит отдельно поискать корреляцию')
# Out:
# respiratory_rate
#
# Выбросы через межквартильный размах
# 3      84.0
# 9       NaN
# 29      NaN
# 32      NaN
# 38      NaN
# 50      NaN
# 61      NaN
# 66      NaN
# 75      NaN
# 82     80.0
# 84     80.0
# 103    68.0
# 120    66.0
# 125    68.0
# 137     NaN
# 138     NaN
# 146     NaN
# 164     NaN
# 179     NaN
# 186    90.0
# 201     NaN
# 205     NaN
# 208    80.0
# 238     NaN
# 244    88.0
# 249     NaN
# 255    84.0
# 256     NaN
# 265    68.0
# 269    90.0
# 271     NaN
# 281     NaN
# 284     NaN
# 295    70.0
# Name: respiratory_rate, dtype: float64
# Разница со средним без выбросов  3.166980904036741
# Разница с медианой без выбросов  3.0
#
# Выбросы через 0.01-0.99 квантиль
# 9       NaN
# 29      NaN
# 32      NaN
# 38      NaN
# 50      NaN
# 61      NaN
# 66      NaN
# 75      NaN
# 137     NaN
# 138     NaN
# 140     9.0
# 146     NaN
# 164     NaN
# 179     NaN
# 186    90.0
# 190     8.0
# 201     NaN
# 203     9.0
# 205     NaN
# 238     NaN
# 244    88.0
# 249     NaN
# 256     NaN
# 269    90.0
# 271     NaN
# 281     NaN
# 284     NaN
# Name: respiratory_rate, dtype: float64
# Разница среднего со средним без выбросов  3.166980904036741
# Разница медианы с медианой без выбросов  3.0
# Максимум  90.0
# Новый Максимум0  60.0
# Новый Максимум1  84.0
# Минимум  8.0
# Новый Минимум0  8.0
# Новый Минимум1  10.0
# Размах  82.0
# Новый Размах0  52.0
# Новый Размах1  74.0
# Среднеарифметическое  30.16190476190476
# Новое Среднеарифметическое0  26.99492385786802
# Новое Среднеарифметическое1  29.607843137254903
# Мода  20.0
# Новая Мода0  20.0
# Новая Мода1  20.0
# Медиана  27.0
# Новая Медиана0  24.0
# Новая Медиана1  27.0
# Второй квартиль (50% квантиль)  27.0
# Новый Второй квартиль0 (50% квантиль)  24.0
# Новый Второй квартиль1 (50% квантиль)  27.0
# Первый квартиль (25% квантиль)  20.0
# Новый Первый квартиль0 (25% квантиль)  18.0
# Новый Первый квартиль1 (25% квантиль)  20.0
# Третий квартиль (75% квантиль)  36.0
# Новый Третий квартиль0 (75% квантиль)  36.0
# Новый Третий квартиль1 (75% квантиль)  36.0
# Межквартильный размах  16.0
# Новый Межквартильный размах0  18.0
# Новый Межквартильный размах1  18.0
# СКО (среднее отклонение)  16.896319810798474
# Новое СКО (среднее отклонение)0  11.686595086403939
# Новое СКО (среднее отклонение)1  15.330613863554227
# Дисперсия  285.48562314878103
# Новая Дисперсия0  136.57650471356067
# Новая Дисперсия1  235.02772143340104
# Вывод: осталось 21 строки с пропусками из 231, столбец теперь можно учитывать в статистиках (согласно мнению лектора о 20%)
# Прежний Вывод (верный): подтвердилось примечание из описания - слишком большие колебания по сравнению с нормой (8-10)
# Новый Вывод: соотношение выбросов/пропусков к общему числу элементов близко к rectal_temperature, стоит отдельно поискать корреляцию

# %%
print_stats('temperature_of_extremities')
print('Вывод: 15 из 231 являются выбросами (точнее пропусками), это меньше 20%, статистику можно применять дальше, отсекание выбросов ни на что не повлияло (пропуски и так не учитываются)')
print('Прежний Вывод (верный): большинство лошадей имеют пониженную (cool, а не cold) температуру конечностей, что может говорить о шоке')
print('Прежнее Примечание (неточное): для более точных результатов скорее всего необходимо учитывать корреляцию с показателями rectal_temperature и pain')
print('Новое Примечание: соотношение выбросов/пропусков к общему числу элементов близко к rectal_temperature и respiratory_rate, стоит отдельно поискать корреляцию и, если есть, заполнить пропуски в rectal_temperature и respiratory_rate')
# Out:
# temperature_of_extremities
#
# Выбросы через межквартильный размах
# 1     NaN
# 23    NaN
# 90    NaN
# 95    NaN
# 121   NaN
# 128   NaN
# 149   NaN
# 181   NaN
# 190   NaN
# 210   NaN
# 239   NaN
# 260   NaN
# 263   NaN
# 280   NaN
# 289   NaN
# Name: temperature_of_extremities, dtype: float64
# Разница со средним без выбросов  0.0
# Разница с медианой без выбросов  0.0
#
# Выбросы через 0.01-0.99 квантиль
# 1     NaN
# 23    NaN
# 90    NaN
# 95    NaN
# 121   NaN
# 128   NaN
# 149   NaN
# 181   NaN
# 190   NaN
# 210   NaN
# 239   NaN
# 260   NaN
# 263   NaN
# 280   NaN
# 289   NaN
# Name: temperature_of_extremities, dtype: float64
# Разница среднего со средним без выбросов  0.0
# Разница медианы с медианой без выбросов  0.0
# Максимум  4.0
# Новый Максимум0  4.0
# Новый Максимум1  4.0
# Минимум  1.0
# Новый Минимум0  1.0
# Новый Минимум1  1.0
# Размах  3.0
# Новый Размах0  3.0
# Новый Размах1  3.0
# Среднеарифметическое  2.2916666666666665
# Новое Среднеарифметическое0  2.2916666666666665
# Новое Среднеарифметическое1  2.2916666666666665
# Мода  3.0
# Новая Мода0  3.0
# Новая Мода1  3.0
# Медиана  3.0
# Новая Медиана0  3.0
# Новая Медиана1  3.0
# Второй квартиль (50% квантиль)  3.0
# Новый Второй квартиль0 (50% квантиль)  3.0
# Новый Второй квартиль1 (50% квантиль)  3.0
# Первый квартиль (25% квантиль)  1.0
# Новый Первый квартиль0 (25% квантиль)  1.0
# Новый Первый квартиль1 (25% квантиль)  1.0
# Третий квартиль (75% квантиль)  3.0
# Новый Третий квартиль0 (75% квантиль)  3.0
# Новый Третий квартиль1 (75% квантиль)  3.0
# Межквартильный размах  2.0
# Новый Межквартильный размах0  2.0
# Новый Межквартильный размах1  2.0
# СКО (среднее отклонение)  1.0535101902355917
# Новое СКО (среднее отклонение)0  1.0535101902355917
# Новое СКО (среднее отклонение)1  1.0535101902355917
# Дисперсия  1.1098837209302324
# Новая Дисперсия0  1.1098837209302324
# Новая Дисперсия1  1.1098837209302324
# Вывод: 15 из 231 являются выбросами (точнее пропусками), это меньше 20%, статистику можно применять дальше, отсекание выбросов ни на что не повлияло (пропуски и так не учитываются)
# Прежний Вывод (верный): большинство лошадей имеют пониженную (cool, а не cold) температуру конечностей, что может говорить о шоке
# Прежнее Примечание (неточное): для более точных результатов скорее всего необходимо учитывать корреляцию с показателями rectal_temperature и pain
# Новое Примечание: соотношение выбросов/пропусков к общему числу элементов близко к rectal_temperature и respiratory_rate, стоит отдельно поискать корреляцию и, если есть, заполнить пропуски в rectal_temperature и respiratory_rate

# %%
print_stats('pain')
print('Вывод: 15 из 300 являются выбросами (точнее пропусками), это меньше 20%, статистику можно применять дальше, отсекание выбросов ни на что не повлияло (пропуски и так не учитываются)')
print('Прежний Вывод (верный): оценка боли скорее всего имеет нормальное распределение')
print('Прежнее Примечание (верное): если другие столбцы имеют корреляцию с этим, можно наверное заполнить пропуски для тех столбцов')
print('Новое Примечание: стоит поискать корреляцию с rectal_temperature, respiratory_rate и temperature_of_extremities')
# Out:
# pain
#
# Выбросы через межквартильный размах
# 19    NaN
# 24    NaN
# 27    NaN
# 94    NaN
# 157   NaN
# 170   NaN
# 185   NaN
# 186   NaN
# 195   NaN
# 208   NaN
# 213   NaN
# 234   NaN
# 243   NaN
# 257   NaN
# 269   NaN
# Name: pain, dtype: float64
# Разница со средним без выбросов  0.0
# Разница с медианой без выбросов  0.0
#
# Выбросы через 0.01-0.99 квантиль
# 19    NaN
# 24    NaN
# 27    NaN
# 94    NaN
# 157   NaN
# 170   NaN
# 185   NaN
# 186   NaN
# 195   NaN
# 208   NaN
# 213   NaN
# 234   NaN
# 243   NaN
# 257   NaN
# 269   NaN
# Name: pain, dtype: float64
# Разница среднего со средним без выбросов  0.0
# Разница медианы с медианой без выбросов  0.0
# Максимум  5.0
# Новый Максимум0  5.0
# Новый Максимум1  5.0
# Минимум  1.0
# Новый Минимум0  1.0
# Новый Минимум1  1.0
# Размах  4.0
# Новый Размах0  4.0
# Новый Размах1  4.0
# Среднеарифметическое  2.8333333333333335
# Новое Среднеарифметическое0  2.8333333333333335
# Новое Среднеарифметическое1  2.8333333333333335
# Мода  3.0
# Новая Мода0  3.0
# Новая Мода1  3.0
# Медиана  3.0
# Новая Медиана0  3.0
# Новая Медиана1  3.0
# Второй квартиль (50% квантиль)  3.0
# Новый Второй квартиль0 (50% квантиль)  3.0
# Новый Второй квартиль1 (50% квантиль)  3.0
# Первый квартиль (25% квантиль)  2.0
# Новый Первый квартиль0 (25% квантиль)  2.0
# Новый Первый квартиль1 (25% квантиль)  2.0
# Третий квартиль (75% квантиль)  4.0
# Новый Третий квартиль0 (75% квантиль)  4.0
# Новый Третий квартиль1 (75% квантиль)  4.0
# Межквартильный размах  2.0
# Новый Межквартильный размах0  2.0
# Новый Межквартильный размах1  2.0
# СКО (среднее отклонение)  1.2575354264740255
# Новое СКО (среднее отклонение)0  1.2575354264740255
# Новое СКО (среднее отклонение)1  1.2575354264740255
# Дисперсия  1.5813953488372092
# Новая Дисперсия0  1.5813953488372092
# Новая Дисперсия1  1.5813953488372092
# Вывод: 15 из 300 являются выбросами (точнее пропусками), это меньше 20%, статистику можно применять дальше, отсекание выбросов ни на что не повлияло (пропуски и так не учитываются)
# Прежний Вывод (верный): оценка боли скорее всего имеет нормальное распределение
# Прежнее Примечание (верное): если другие столбцы имеют корреляцию с этим, можно наверное заполнить пропуски для тех столбцов
# Новое Примечание: стоит поискать корреляцию с rectal_temperature, respiratory_rate и temperature_of_extremities

# %%
print_stats('outcome')
print('Вывод: Единственный пропуск без значения surgery - удалили строку')
print('Прежний Вывод (верный): Большинство лошадей выжили после лечения')
print('Прежнее Примечание (без обновлений): для более точных результатов скорее всего необходимо учитывать корреляцию с показателем pain, точнее со значениями 4 и тем более 5')
# Out:
# outcome
#
# Выбросы через межквартильный размах
# Series([], Name: outcome, dtype: float64)
# Разница со средним без выбросов  0.0
# Разница с медианой без выбросов  0.0
#
# Выбросы через 0.01-0.99 квантиль
# Series([], Name: outcome, dtype: float64)
# Разница среднего со средним без выбросов  0.0
# Разница медианы с медианой без выбросов  0.0
# Максимум  3.0
# Новый Максимум0  3.0
# Новый Максимум1  3.0
# Минимум  1.0
# Новый Минимум0  1.0
# Новый Минимум1  1.0
# Размах  2.0
# Новый Размах0  2.0
# Новый Размах1  2.0
# Среднеарифметическое  1.5194805194805194
# Новое Среднеарифметическое0  1.5194805194805194
# Новое Среднеарифметическое1  1.5194805194805194
# Мода  1.0
# Новая Мода0  1.0
# Новая Мода1  1.0
# Медиана  1.0
# Новая Медиана0  1.0
# Новая Медиана1  1.0
# Второй квартиль (50% квантиль)  1.0
# Новый Второй квартиль0 (50% квантиль)  1.0
# Новый Второй квартиль1 (50% квантиль)  1.0
# Первый квартиль (25% квантиль)  1.0
# Новый Первый квартиль0 (25% квантиль)  1.0
# Новый Первый квартиль1 (25% квантиль)  1.0
# Третий квартиль (75% квантиль)  2.0
# Новый Третий квартиль0 (75% квантиль)  2.0
# Новый Третий квартиль1 (75% квантиль)  2.0
# Межквартильный размах  1.0
# Новый Межквартильный размах0  1.0
# Новый Межквартильный размах1  1.0
# СКО (среднее отклонение)  0.7391603275584075
# Новое СКО (среднее отклонение)0  0.7391603275584075
# Новое СКО (среднее отклонение)1  0.7391603275584075
# Дисперсия  0.5463579898362524
# Новая Дисперсия0  0.5463579898362524
# Новая Дисперсия1  0.5463579898362524
# Вывод: Единственный пропуск без значения surgery - удалили строку
# Прежний Вывод (верный): Большинство лошадей выжили после лечения
# Прежнее Примечание (без обновлений): для более точных результатов скорее всего необходимо учитывать корреляцию с показателем pain, точнее со значениями 4 и тем более 5
